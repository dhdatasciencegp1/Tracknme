# %%
# importando as bibiotecas
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import seaborn as sns
import scipy
from scipy import stats
import matplotlib.pyplot as plt
# %matplotlib inline
# ignorando os warnings
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv(r'Dados_tracknMe/dataset_esposa', encoding = 'latin1', engine = 'python' , delimiter = ',')

# %%
df.head()
# Out:
#    ï»¿"content__id"   content__device    content__dateTime  \
# 0  6419624909602816  5811846699810816  2020-03-22T13:48:23
# 1  5656361640919040  5811846699810816  2020-03-22T13:47:22
# 2  5885231858188288  5811846699810816  2020-03-22T13:46:22
# 3  4990971751432192  5811846699810816  2020-03-22T13:45:21
# 4  5070364255453184  5811846699810816  2020-03-22T13:44:22
#
#   content__gprsDateTime  content__latitude  content__longitude  \
# 0   2020-03-22T13:47:26         -23.627757          -46.730580
# 1   2020-03-22T13:46:35         -23.630483          -46.729972
# 2   2020-03-22T13:45:33         -23.634252          -46.723885
# 3   2020-03-22T13:44:23         -23.624982          -46.711548
# 4   2020-03-22T13:43:23         -23.612763          -46.700392
#
#    content__speed  content__valid  content__geolocate  content__identifier  \
# 0        0.000000            True               False           1602154756
# 1       36.299202            True               False           1602154756
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 54 columns):
# ï»¿"content__id"                 211 non-null int64
# content__device                  211 non-null int64
# content__dateTime                211 non-null object
# content__gprsDateTime            211 non-null object
# content__latitude                211 non-null float64
# content__longitude               211 non-null float64
# content__speed                   211 non-null float64
# content__valid                   211 non-null bool
# content__geolocate               211 non-null bool
# content__identifier              211 non-null int64
# content__battery                 211 non-null int64
# content__movement                211 non-null object
# content__parkingStart            4 non-null object
# content__parkingEnd              4 non-null object
# content__accelerationCount       211 non-null int64
# content__decelerationCount       211 non-null int64
# ...

# %%
df[['content__speed','content__battery','totalPages']].hist(bins=50, figsize=(20,15))
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 211 entries, 0 to 210
# Data columns (total 54 columns):
# ï»¿"content__id"                 211 non-null int64
# content__device                  211 non-null int64
# content__dateTime                211 non-null object
# content__gprsDateTime            211 non-null object
# content__latitude                211 non-null float64
# content__longitude               211 non-null float64
# content__speed                   211 non-null float64
# content__valid                   211 non-null bool
# content__geolocate               211 non-null bool
# content__identifier              211 non-null int64
# content__battery                 211 non-null int64
# content__movement                211 non-null object
# content__parkingStart            4 non-null object
# content__parkingEnd              4 non-null object
# content__accelerationCount       211 non-null int64
# content__decelerationCount       211 non-null int64
# ...

# %%
df.plot(kind="scatter", x = "content__longitude" , y ="content__latitude")

# %%
df.plot(kind="scatter", x = "content__longitude" , y ="content__latitude" , alpha = 0.5)

# %%
df.plot(kind="scatter", x = "content__longitude" , y ="content__latitude" , alpha = 0.5,
       c = "content__speed", cmap=plt.get_cmap("jet"))
